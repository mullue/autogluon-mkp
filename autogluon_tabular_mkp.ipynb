# %% [markdown]
# # AutoGluon-Tabular in AWS Marketplace
#
# 본 노트북은 다음 aws 예제에 대한 한글 번역입니다.
# - https://github.com/aws/amazon-sagemaker-examples/tree/master/aws_marketplace/using_algorithms/autogluon
#
# [AutoGluon](https://github.com/awslabs/autogluon) 은 머신리닝을 자동화하여 여러분의 응용프로그램에 쉽게 강력한 예측성능을 제공할 수 있도록 합니다. 몇줄의 코드만으로 여러분은 테이블, 이미지, 텍스트데이터에 대하여 고성능의 딥러닝 모델을 학습하고 배포할 수 있습니다. 본 노트북은 테이블형식의 데이터에 대하여 AWS마켓플레이스에 있는 AutoGluon-Tabluar 를 어떻게 적용하는지 보여드립니다.
#
#
# ### Contents:
# * [Step 1: Subscribe to AutoML algorithm from AWS Marketplace](#Step-1:-Subscribe-to-AutoML-algorithm-from-AWS-Marketplace)
# * [Step 2: Set up environment](#Step-2-:-Set-up-environment)
# * [Step 3: Prepare and upload data](#Step-3:-Prepare-and-upload-data)
# * [Step 4: Train a model](#Step-4:-Train-a-model)
# * [Step 5: Deploy the model and perform a real-time inference](#Step-5:-Deploy-the-model-and-perform-a-real-time-inference)
# * [Step 6: Use Batch Transform](#Step-6:-Use-Batch-Transform)
# * [Step 7: Clean-up](#Step-7:-Clean-up)

# %% [markdown]
# ### Step 1: Subscribe to AutoML algorithm from AWS Marketplace
#
# 1. 마켓플레이스에 접속하고 [AutoGluon-Tabular](https://aws.amazon.com/marketplace/pp/prodview-n4zf5pmjt7ism) 페이지를 오픈합니다.
# 2. **Highlights** 부분과 **product overview** 부분을 읽어봅니다. (알고리즘의 개요와 동작특성, 특장점 등을 설명하고 있습니다.)
# 3. **usage information** 부분과 **additional resources** 부분을 살펴봅니다. (알고리즘의 사용방법이 설명됩니다.)
# 4. 지원되는 인스턴스 타입을 살펴봅니다. 본 노트북의 이후 셀에서 해당 타입을 설정할 것입니다.
# 5. **Continue to subscribe** 버튼을 클릭합니다.
# 6. **End user license agreement**, **support terms**, **pricing information**을 읽어봅니다.
# 7. 여러분의 조직에서 해당 알고리즘의 라이센스, 가격, 지원정책에 동의하는 경우 **Accept offer** 버튼을 클릭합니다.
#
# **Notes**:
# 1. **Continue to configuration** 버튼이 활성회되면 여러분의 어카운트가 subscription 된 상태입니다.
# 2. **Continue to configuration** 버튼을 클릭하고 리전을 선택하면 `Product Arn`을 확인할 수 있습니다. 이 값이 여러분의 학습작업에서 사용할 알고리즘 ARN입니다. (단, 본 노트북에서는 이미 리전별 ARN 값들을 **src/algorithm_arns.py** 파일에 저장해 두었기 때문에 특별히 설정할 필요는 없습니다.)

# %% [markdown]
# ### Step 2 : Set up environment

# %%
# Import the latest sagemaker and boto3 SDKs
import sys
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install -qU awscli boto3 "sagemaker>=2.0.0" tqdm
# !{sys.executable} -m pip show sagemaker
# Out:
# Requirement already up-to-date: pip in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (20.2.4)
# Name: sagemaker
# Version: 2.16.3
# Summary: Open source library for training and deploying models on Amazon SageMaker.
# Home-page: https://github.com/aws/sagemaker-python-sdk/
# Author: Amazon Web Services
# Author-email: None
# License: Apache License 2.0
# Location: /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages
# Requires: boto3, smdebug-rulesconfig, protobuf, google-pasta, protobuf3-to-dict, importlib-metadata, numpy, packaging
# Required-by:

# %%
#Import necessary libraries.
import os
import boto3
import sagemaker
from time import sleep
from collections import Counter
import numpy as np
import pandas as pd
from sagemaker import get_execution_role, local, Model, utils, fw_utils, s3
from sagemaker import AlgorithmEstimator
from sagemaker.predictor import RealTimePredictor, csv_serializer, StringDeserializer
from sklearn.metrics import accuracy_score, classification_report
from IPython.core.display import display, HTML
from IPython.core.interactiveshell import InteractiveShell

# Print settings
InteractiveShell.ast_node_interactivity = "all"
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 10)

# Account/s3 setup
session = sagemaker.Session()
bucket = session.default_bucket()
prefix = 'sagemaker/autogluon-tabular'
region = session.boto_region_name
role = get_execution_role()

# %%
compatible_training_instance_type='ml.m5.4xlarge' 
compatible_inference_instance_type='ml.m5.4xlarge'

# %%
#Specify algorithm ARN for AutoGluon-Tabular from AWS Marketplace.  However, for this notebook, the algorithm ARN 
#has been specified in src/algorithm_arns.py file and you do not need to specify the same explicitly.

from src.algorithm_arns import AlgorithmArnProvider

algorithm_arn = AlgorithmArnProvider.get_algorithm_arn(region)

# %% [markdown]
# ### Step 3: Get the data
#
# 본 샘플에서는 다이렉트 마케팅 데이터셋을 사용하여 고객이 마케팅 제안을 수용할지 거절할 지 예측하는 이진 분류 모델을 만들 것입니다.
# 우선 데이터를 다운로드하고 학습(train), 테스트용(test) 셋으로 나눕니다. AutoGluon 이용시 별도의 검증(validation)셋의 생성은 필요하지 않습니다. (내부적으로 k-fold cross-validation을 이용합니다.)

# %%
# Download and unzip the data
# !aws s3 cp --region {region} s3://sagemaker-sample-data-{region}/autopilot/direct_marketing/bank-additional.zip .
# !unzip -qq -o bank-additional.zip
# !rm bank-additional.zip

local_data_path = './bank-additional/bank-additional-full.csv'
data = pd.read_csv(local_data_path)

# Split train/test data
train = data.sample(frac=0.7, random_state=42)
test = data.drop(train.index)

# Split test X/y
label = 'y'
y_test = test[label]
X_test = test.drop(columns=[label])
# Out:
# download: s3://sagemaker-sample-data-us-east-1/autopilot/direct_marketing/bank-additional.zip to ./bank-additional.zip

# %% [markdown]
# #### 데이터 확인
#
# - train, test 데이터는 레이블 컬럼 `y`를 포함하고 있습니다.
# - X_test 데이터는 레이블 컬럼 `y`를 포함하고 있지 않습니다.

# %%
train.head(3)
train.shape

test.head(3)
test.shape

X_test.head(3)
X_test.shape
# Out:
#        age          job  marital    education  default housing loan  \
# 32884   57   technician  married  high.school       no      no  yes
# 3169    55      unknown  married      unknown  unknown     yes   no
# 32206   33  blue-collar  married     basic.9y       no      no   no
#
#          contact month day_of_week  duration  campaign  pdays  previous  \
# 32884   cellular   may         mon       371         1    999         1
# 3169   telephone   may         thu       285         2    999         0
# 32206   cellular   may         fri        52         1    999         1
#
#           poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 32884      failure          -1.8          92.893          -46.2      1.299
# 3169   nonexistent           1.1          93.994          -36.4      4.860
# 32206      failure          -1.8          92.893          -46.2      1.313
#
#        nr.employed   y
# 32884       5099.1  no
# 3169        5191.0  no
# 32206       5099.1  no
# (28832, 21)
#     age          job  marital    education  default housing loan    contact  \
# 2    37     services  married  high.school       no     yes   no  telephone
# 9    25     services   single  high.school       no     yes   no  telephone
# 10   41  blue-collar  married      unknown  unknown      no   no  telephone
#
#    month day_of_week  duration  campaign  pdays  previous     poutcome  \
# 2    may         mon       226         1    999         0  nonexistent
# 9    may         mon        50         1    999         0  nonexistent
# 10   may         mon        55         1    999         0  nonexistent
#
#     emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 2            1.1          93.994          -36.4      4.857       5191.0  no
# 9            1.1          93.994          -36.4      4.857       5191.0  no
# 10           1.1          93.994          -36.4      4.857       5191.0  no
# (12356, 21)
#     age          job  marital    education  default housing loan    contact  \
# 2    37     services  married  high.school       no     yes   no  telephone
# 9    25     services   single  high.school       no     yes   no  telephone
# 10   41  blue-collar  married      unknown  unknown      no   no  telephone
#
#    month day_of_week  duration  campaign  pdays  previous     poutcome  \
# 2    may         mon       226         1    999         0  nonexistent
# 9    may         mon        50         1    999         0  nonexistent
# 10   may         mon        55         1    999         0  nonexistent
#
#     emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# 2            1.1          93.994          -36.4      4.857       5191.0
# 9            1.1          93.994          -36.4      4.857       5191.0
# 10           1.1          93.994          -36.4      4.857       5191.0
# (12356, 20)

# %% [markdown]
# 데이터를 S3로 업로드합니다.

# %%
train_file = 'train.csv'
train.to_csv(train_file,index=False)
train_s3_path = session.upload_data(train_file, key_prefix='{}/data'.format(prefix))

test_file = 'test.csv'
test.to_csv(test_file,index=False)
test_s3_path = session.upload_data(test_file, key_prefix='{}/data'.format(prefix))

X_test_file = 'X_test.csv'
X_test.to_csv(X_test_file,index=False)
X_test_s3_path = session.upload_data(X_test_file, key_prefix='{}/data'.format(prefix))

# %% [markdown]
# ### Step 4: Train a model
#
# 이제 모델을 학습하겠습니다.
#
# **주의:** 적절한 디스크 사이즈 할당을 위해 `train_volume_size`값을 조정해야 할 수 있습니다.

# %%
# Define required label and optional additional parameters
fit_args = {
  'label': 'y',
  # Adding 'best_quality' to presets list will result in better performance (but longer runtime)
  'presets': ['optimize_for_deployment'],
}

# Pass fit_args to SageMaker estimator hyperparameters
hyperparameters = {
  'fit_args': fit_args,
  'feature_importance': True
}

# %%
algo = AlgorithmEstimator(algorithm_arn=algorithm_arn, 
                          role=role, 
                          instance_count=1, 
                          instance_type=compatible_training_instance_type, 
                          sagemaker_session=session, 
                          base_job_name='autogluon',
                          hyperparameters=hyperparameters,
                          train_volume_size=100) 

inputs = {'training': train_s3_path}

algo.fit(inputs)
# Out:
# 2020-11-16 11:34:31 Starting - Starting the training job...
# 2020-11-16 11:34:32 Starting - Launching requested ML instances......
# 2020-11-16 11:35:47 Starting - Preparing the instances for training...
# 2020-11-16 11:36:18 Downloading - Downloading input data...
# 2020-11-16 11:36:35 Training - Downloading the training image......
# 2020-11-16 11:37:52 Training - Training image download completed. Training in progress.2020-11-16 11:37:52,078 sagemaker-training-toolkit INFO     Imported framework sagemaker_mxnet_container.training
# 2020-11-16 11:37:52,080 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-11-16 11:37:52,080 sagemaker-training-toolkit INFO     Failed to parse hyperparameter fit_args value {'label': 'y', 'presets': ['optimize_for_deployment']} to Json.
# Returning the value itself
# 2020-11-16 11:37:52,080 sagemaker-training-toolkit INFO     Failed to parse hyperparameter feature_importance value True to Json.
# Returning the value itself
# 2020-11-16 11:37:52,091 sagemaker_mxnet_container.training INFO     MXNet training environment: {'SM_HOSTS': '["algo-1"]', 'SM_NETWORK_INTERFACE_NAME': 'eth0', 'SM_HPS': '{"feature_importance":"True","fit_args":"{\'label\': \'y\', \'presets\': [\'optimize_for_deployment\']}"}', 'SM_USER_ENTRY_POINT': 'train.py', 'SM_FRAMEWORK_PARAMS': '{}', 'SM_RESOURCE_CONFIG': '{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}', 'SM_INPUT_DATA_CONFIG': '{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}', 'SM_OUTPUT_DATA_DIR': '/opt/ml/output/data', 'SM_CHANNELS': '["training"]', 'SM_CURRENT_HOST': 'algo-1', 'SM_MODULE_NAME': 'train', 'SM_LOG_LEVEL': '20', 'SM_FRAMEWORK_MODULE': 'sagemaker_mxnet_container.training:main', 'SM_INPUT_DIR': '/opt/ml/input', 'SM_INPUT_CONFIG_DIR': '/opt/ml/input/config', 'SM_OUTPUT_DIR': '/opt/ml/output', 'SM_NUM_CPUS': '16', 'SM_NUM_GPUS': '0', 'SM_MODEL_DIR': '/opt/ml/model', 'SM_MODULE_DIR': '/opt/ml/code', 'SM_TRAINING_ENV': '{"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_mxnet_container.training:main","hosts":["algo-1"],"hyperparameters":{"feature_importance":"True","fit_args":"{\'label\': \'y\', \'presets\': [\'optimize_for_deployment\']}"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"autogluon-2020-11-16-11-34-30-896","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"train","network_interface_name":"eth0","num_cpus":16,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}', 'SM_USER_ARGS': '["--feature_importance","True","--fit_args","{\'label\': \'y\', \'presets\': [\'optimize_for_deployment\']}"]', 'SM_OUTPUT_INTERMEDIATE_DIR': '/opt/ml/output/intermediate', 'SM_CHANNEL_TRAINING': '/opt/ml/input/data/training', 'SM_HP_FIT_ARGS': "{'label': 'y', 'presets': ['optimize_for_deployment']}", 'SM_HP_FEATURE_IMPORTANCE': 'True'}
# 2020-11-16 11:37:52,093 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-11-16 11:37:52,094 sagemaker-training-toolkit INFO     Failed to parse hyperparameter fit_args value {'label': 'y', 'presets': ['optimize_for_deployment']} to Json.
# Returning the value itself
# 2020-11-16 11:37:52,094 sagemaker-training-toolkit INFO     Failed to parse hyperparameter feature_importance value True to Json.
# Returning the value itself
# 2020-11-16 11:37:53,539 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-11-16 11:37:53,539 sagemaker-training-toolkit INFO     Failed to parse hyperparameter fit_args value {'label': 'y', 'presets': ['optimize_for_deployment']} to Json.
# Returning the value itself
# 2020-11-16 11:37:53,539 sagemaker-training-toolkit INFO     Failed to parse hyperparameter feature_importance value True to Json.
# Returning the value itself
# 2020-11-16 11:37:53,551 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-11-16 11:37:53,552 sagemaker-training-toolkit INFO     Failed to parse hyperparameter fit_args value {'label': 'y', 'presets': ['optimize_for_deployment']} to Json.
# Returning the value itself
# 2020-11-16 11:37:53,552 sagemaker-training-toolkit INFO     Failed to parse hyperparameter feature_importance value True to Json.
# Returning the value itself
# 2020-11-16 11:37:53,563 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_mxnet_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "fit_args": "{'label': 'y', 'presets': ['optimize_for_deployment']}",
#         "feature_importance": "True"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "autogluon-2020-11-16-11-34-30-896",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "/opt/ml/code",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 16,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"feature_importance":"True","fit_args":"{'label': 'y', 'presets': ['optimize_for_deployment']}"}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_mxnet_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=16
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=/opt/ml/code
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_mxnet_container.training:main","hosts":["algo-1"],"hyperparameters":{"feature_importance":"True","fit_args":"{'label': 'y', 'presets': ['optimize_for_deployment']}"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"autogluon-2020-11-16-11-34-30-896","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"train","network_interface_name":"eth0","num_cpus":16,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--feature_importance","True","--fit_args","{'label': 'y', 'presets': ['optimize_for_deployment']}"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_FIT_ARGS={'label': 'y', 'presets': ['optimize_for_deployment']}
# SM_HP_FEATURE_IMPORTANCE=True
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python36.zip:/usr/local/lib/python3.6:/usr/local/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /usr/local/bin/python3.6 train.py --feature_importance True --fit_args {'label': 'y', 'presets': ['optimize_for_deployment']}
#
#
# fit_args:
# label,  type: <class 'str'>,  value: y
# presets,  type: <class 'list'>,  value: ['optimize_for_deployment']
# Train files: ['train.csv']
# Beginning AutoGluon training ...
# AutoGluon will save models to /opt/ml/model/
# AutoGluon Version:  0.0.12b20200702
# Train Data Rows:    28832
# Train Data Columns: 21
# Preprocessing data ...
# Here are the 2 unique label values in your data:  ['no', 'yes']
# AutoGluon infers your prediction problem is: binary  (because only two unique label-values observed).
# If this is wrong, please specify `problem_type` argument in fit() instead (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
#
# Selected class <--> label mapping:  class 1 = yes, class 0 = no
# Train Data Class Count: 2
# Feature Generator processed 28832 data points with 20 features
# Original Features:
# #011int features: 5
# #011object features: 10
# #011float features: 5
# Generated Features:
# #011int features: 0
# All Features:
# #011int features: 5
# #011object features: 10
# #011float features: 5
# #011Data preprocessing and feature engineering runtime = 0.22s ...
# AutoGluon will gauge predictive performance using evaluation metric: accuracy
# To change this, specify the eval_metric argument of fit()
# AutoGluon will early stop models using evaluation metric: accuracy
# Fitting model: RandomForestClassifierGini ...
# #0110.9168#011 = Validation accuracy score
# #0111.24s#011 = Training runtime
# #0110.12s#011 = Validation runtime
# Fitting model: RandomForestClassifierEntr ...
# #0110.9188#011 = Validation accuracy score
# #0111.24s#011 = Training runtime
# #0110.12s#011 = Validation runtime
# Fitting model: ExtraTreesClassifierGini ...
# #0110.9132#011 = Validation accuracy score
# #0111.04s#011 = Training runtime
# #0110.22s#011 = Validation runtime
# Fitting model: ExtraTreesClassifierEntr ...
# #0110.9124#011 = Validation accuracy score
# #0111.14s#011 = Training runtime
# #0110.12s#011 = Validation runtime
# Fitting model: KNeighborsClassifierUnif ...
# #0110.9048#011 = Validation accuracy score
# #0110.18s#011 = Training runtime
# #0110.11s#011 = Validation runtime
# Fitting model: KNeighborsClassifierDist ...
# #0110.9032#011 = Validation accuracy score
# #0110.18s#011 = Training runtime
# #0110.11s#011 = Validation runtime
# Fitting model: LightGBMClassifier ...
# #0110.926#011 = Validation accuracy score
# #0110.32s#011 = Training runtime
# #0110.02s#011 = Validation runtime
# Fitting model: CatboostClassifier ...
# #0110.9264#011 = Validation accuracy score
# #0111.57s#011 = Training runtime
# #0110.02s#011 = Validation runtime
# Fitting model: NeuralNetClassifier ...
# #0110.9248#011 = Validation accuracy score
# #01132.65s#011 = Training runtime
# #0110.21s#011 = Validation runtime
# Fitting model: LightGBMClassifierCustom ...
# #0110.9232#011 = Validation accuracy score
# #0110.99s#011 = Training runtime
# #0110.02s#011 = Validation runtime
# Fitting model: weighted_ensemble_k0_l1 ...
# #0110.93#011 = Validation accuracy score
# #0111.12s#011 = Training runtime
# #0110.0s#011 = Validation runtime
# AutoGluon training complete, total runtime = 45.89s ...
# Deleting model RandomForestClassifierEntr. All files under /opt/ml/model/models/RandomForestClassifierEntr/ will be removed.
# Deleting model ExtraTreesClassifierGini. All files under /opt/ml/model/models/ExtraTreesClassifierGini/ will be removed.
# Deleting model ExtraTreesClassifierEntr. All files under /opt/ml/model/models/ExtraTreesClassifierEntr/ will be removed.
# Deleting model KNeighborsClassifierUnif. All files under /opt/ml/model/models/KNeighborsClassifierUnif/ will be removed.
# Deleting model KNeighborsClassifierDist. All files under /opt/ml/model/models/KNeighborsClassifierDist/ will be removed.
# *** Summary of fit() ***
# Estimated performance of each model:
#                         model  score_val  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer
# 0     weighted_ensemble_k0_l1     0.9300       0.378729  37.886889                0.001576           1.120075            1       True
# 1          CatboostClassifier     0.9264       0.017941   1.571666                0.017941           1.571666            0       True
# 2          LightGBMClassifier     0.9260       0.016953   0.316860                0.016953           0.316860            0       True
# 3         NeuralNetClassifier     0.9248       0.205218  32.648905                0.205218          32.648905            0       True
# 4    LightGBMClassifierCustom     0.9232       0.019981   0.985550                0.019981           0.985550            0       True
# 5  RandomForestClassifierGini     0.9168       0.117060   1.243834                0.117060           1.243834            0       True
# Number of models trained: 6
# Types of models trained:
# {'XTModel', 'TabularNeuralNetModel', 'WeightedEnsembleModel', 'KNNModel', 'LGBModel', 'RFModel', 'CatboostModel'}
# Bagging used: False
# Stack-ensembling used: False
# Hyperparameter-tuning used: False
# User-specified hyperparameters:
# {'default': {'NN': [{}], 'GBM': [{}], 'CAT': [{}], 'RF': [{'criterion': 'gini', 'AG_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'AG_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}], 'XT': [{'criterion': 'gini', 'AG_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'AG_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}], 'KNN': [{'weights': 'uniform', 'AG_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'AG_args': {'name_suffix': 'Dist'}}], 'custom': [{'num_boost_round': 10000, 'num_threads': -1, 'objective': 'binary', 'verbose': -1, 'boosting_type': 'gbdt', 'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 5, 'two_round': True, 'seed_value': 0, 'AG_args': {'model_type': 'GBM', 'name_suffix': 'Custom', 'disable_in_hpo': True}}]}}
# *** End of fit() summary ***
# Model export summary:
# /opt/ml/model/: ['learner.pkl', 'models']
# /opt/ml/model/models: ['CatboostClassifier', 'trainer.pkl', 'LightGBMClassifierCustom', 'NeuralNetClassifier', 'weighted_ensemble_k0_l1', 'RandomForestClassifierGini', 'LightGBMClassifier']
# /opt/ml/model directory size: 90M
#
# Elapsed time: 46.777 seconds. Training Completed!
# 2020-11-16 11:38:44,892 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2020-11-16 11:39:00 Uploading - Uploading generated training model
# 2020-11-16 11:39:00 Completed - Training job completed
# Training seconds: 162
# Billable seconds: 162

# %% [markdown]
# ### Step 5: Deploy the model and perform a real-time inference

# %% [markdown]
# #### 추론을 위한 엔드포인트 배포

# %%
# %%time

from sagemaker.serializers import CSVSerializer
from sagemaker.deserializers import StringDeserializer

predictor = algo.deploy(1, 
                        compatible_inference_instance_type, 
                        serializer=CSVSerializer(), 
                        deserializer=StringDeserializer())
# Out:
# ..........
# -------------!CPU times: user 228 ms, sys: 12.1 ms, total: 240 ms
# Wall time: 7min 18s

# %% [markdown]
# #### 레이블이 없는 테스트 데이터셋을 이용하여 예측 실행
#
# Endpoint의 생성 및 호출결과는 CloudFront에서도 모니터링 가능합니다.
# - SageMaker 콘솔의 Endpoint 메뉴에서 Ednpoint를 클릭한 후 `View Logs`를 클릭하면 CloudWatch로 연결됩니다.

# %%
results = predictor.predict(X_test.to_csv(index=False)).splitlines()

# Check output
print(Counter(results))
# Out:
# Counter({'no': 11384, 'yes': 972})

# %% [markdown]
# #### 레이블을 포함한 데이터를 이용하여 예측 실행
#
# 엔드포인트 로그에 성능 매트릭이 함께 표시됩니다.
# - CloudWatch Logs에 다음과 유사한 로그가 생성되는지 확인합니다.
#
# ```
# ...
# 2020-11-16 14:36:39,356 [INFO ] W-model-1-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - "precision": 0.9108522195098212,
# 2020-11-16 14:36:39,356 [INFO ] W-model-1-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - "recall": 0.9189057947555843,
# 2020-11-16 14:36:39,356 [INFO ] W-9000-model ACCESS_LOG - /127.0.0.1:50338 "POST /invocations HTTP/1.1" 200 2346
# 2020-11-16 14:36:39,356 [INFO ] W-model-1-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - "f1-score": 0.9124150939348481,
# 2020-11-16 14:36:39,356 [INFO ] W-model-1-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - "support": 12356
# 2020-11-16 14:36:39,356 [INFO ] W-model-1-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         }
# ```

# %%
results = predictor.predict(test.to_csv(index=False)).splitlines()

# Check output
print(Counter(results))
# Out:
# Counter({'no': 11384, 'yes': 972})

# %% [markdown]
# #### 엔드포인트 성능 매트릭 직접 확인
#
# 실제값과 예측결과를 비교하여 실제 분류 성능을 확인해 봅니다.

# %%
y_results = np.array(results)

print("accuracy: {}".format(accuracy_score(y_true=y_test, y_pred=y_results)))
print(classification_report(y_true=y_test, y_pred=y_results, digits=6))
# Out:
# accuracy: 0.9189057947555843
#               precision    recall  f1-score   support
#
#           no   0.937368  0.973631  0.955156     10960
#          yes   0.702675  0.489255  0.576858      1396
#
#     accuracy                       0.918906     12356
#    macro avg   0.820022  0.731443  0.766007     12356
# weighted avg   0.910852  0.918906  0.912415     12356

# %% [markdown]
# ### Step 6: Use Batch Transform

# %% [markdown]
# 이번에는 배치로 추론을 실행해 봅니다. 테스트 데이터셋에 레이블 컬럼을 추가함으로써, 예측 성능을 평가할 수 있습니다. (파라미터로 `X_test_s3_path`가 아닌 `test_s3_path` 를 전달하였습니다.)

# %%
output_path = f's3://{bucket}/{prefix}/output/'

transformer = algo.transformer(instance_count=1, 
                               instance_type=compatible_inference_instance_type,
                               strategy='MultiRecord',
                               max_payload=6,
                               max_concurrent_transforms=1,                              
                               output_path=output_path)

transformer.transform(test_s3_path, content_type='text/csv', split_type='Line')
transformer.wait()
# Out:
# ..........
# ............................2020-11-16T14:53:27.608:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# Warning: Calling MMS with mxnet-model-server. Please move to multi-model-server.
# Warning: Calling MMS with mxnet-model-server. Please move to multi-model-server.
# 2020-11-16 14:53:27,207 [INFO ] main com.amazonaws.ml.mms.ModelServer -
# MMS Home: /usr/local/lib/python3.6/site-packages
# Current directory: /
# Temp directory: /home/model-server/tmp
# Number of GPUs: 0
# Number of CPUs: 16
# Max heap size: 13346 M
# Python executable: /usr/local/bin/python3.6
# Config file: /etc/sagemaker-mms.properties
# Inference address: http://0.0.0.0:8080
# Management address: http://0.0.0.0:8080
# Model Store: /.sagemaker/mms/models
# Initial Models: ALL
# Log dir: /logs
# Metrics dir: /logs
# Netty threads: 0
# Netty client threads: 0
# Default workers per model: 16
# Blacklist Regex: N/A
# Maximum Response Size: 6553500
# Maximum Request Size: 6553500
# Preload model: false
# Prefer direct buffer: false
# 2020-11-16 14:53:27,260 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-9000-model
# 2020-11-16 14:53:27,378 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - model_service_worker started with args: --sock-type unix --sock-name /home/model-server/tmp/.mms.sock.9000 --handler sagemaker_mxnet_serving_container.handler_service --model-path /.sagemaker/mms/models/model --model-name model --preload-model false --tmp-dir /home/model-server/tmp
# 2020-11-16 14:53:27,379 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Listening on port: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,379 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - [PID] 108
# 2020-11-16 14:53:27,207 [INFO ] main com.amazonaws.ml.mms.ModelServer -
# MMS Home: /usr/local/lib/python3.6/site-packages
# Current directory: /
# Temp directory: /home/model-server/tmp
# Number of GPUs: 0
# Number of CPUs: 16
# Max heap size: 13346 M
# Python executable: /usr/local/bin/python3.6
# Config file: /etc/sagemaker-mms.properties
# Inference address: http://0.0.0.0:8080
# Management address: http://0.0.0.0:8080
# Model Store: /.sagemaker/mms/models
# Initial Models: ALL
# Log dir: /logs
# Metrics dir: /logs
# Netty threads: 0
# Netty client threads: 0
# Default workers per model: 16
# Blacklist Regex: N/A
# Maximum Response Size: 6553500
# Maximum Request Size: 6553500
# Preload model: false
# Prefer direct buffer: false
# 2020-11-16 14:53:27,260 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-9000-model
# 2020-11-16 14:53:27,378 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - model_service_worker started with args: --sock-type unix --sock-name /home/model-server/tmp/.mms.sock.9000 --handler sagemaker_mxnet_serving_container.handler_service --model-path /.sagemaker/mms/models/model --model-name model --preload-model false --tmp-dir /home/model-server/tmp
# 2020-11-16 14:53:27,379 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Listening on port: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,379 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - [PID] 108
# 2020-11-16 14:53:27,379 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - MMS worker started.
# 2020-11-16 14:53:27,379 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Python runtime: 3.6.10
# 2020-11-16 14:53:27,380 [INFO ] main com.amazonaws.ml.mms.wlm.ModelManager - Model model loaded.
# 2020-11-16 14:53:27,385 [INFO ] main com.amazonaws.ml.mms.ModelServer - Initialize Inference server with: EpollServerSocketChannel.
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,444 [INFO ] main com.amazonaws.ml.mms.ModelServer - Inference API bind to: http://0.0.0.0:8080
# 2020-11-16 14:53:27,446 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# Model server started.
# 2020-11-16 14:53:27,449 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,449 [WARN ] pool-2-thread-1 com.amazonaws.ml.mms.metrics.MetricCollector - worker pid is not available yet.
# 2020-11-16 14:53:27,450 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,452 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,453 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,454 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,379 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - MMS worker started.
# 2020-11-16 14:53:27,379 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Python runtime: 3.6.10
# 2020-11-16 14:53:27,380 [INFO ] main com.amazonaws.ml.mms.wlm.ModelManager - Model model loaded.
# 2020-11-16 14:53:27,385 [INFO ] main com.amazonaws.ml.mms.ModelServer - Initialize Inference server with: EpollServerSocketChannel.
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,444 [INFO ] main com.amazonaws.ml.mms.ModelServer - Inference API bind to: http://0.0.0.0:8080
# 2020-11-16 14:53:27,446 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# Model server started.
# 2020-11-16 14:53:27,449 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,449 [WARN ] pool-2-thread-1 com.amazonaws.ml.mms.metrics.MetricCollector - worker pid is not available yet.
# 2020-11-16 14:53:27,450 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,452 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,453 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,454 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,456 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,457 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,458 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,459 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,461 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,462 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,463 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,464 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,466 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,467 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,587 [INFO ] pool-1-thread-18 ACCESS_LOG - /169.254.255.130:48830 "GET /ping HTTP/1.1" 200 14
# 2020-11-16 14:53:27,598 [INFO ] epollEventLoopGroup-3-2 ACCESS_LOG - /169.254.255.130:48834 "GET /execution-parameters HTTP/1.1" 404 2
# 2020-11-16 14:53:29,934 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:29,966 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,010 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,010 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,013 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,030 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,030 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,042 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,058 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,067 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,080 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,096 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,118 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,133 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,136 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,212 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:27,456 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,457 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,458 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,459 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,461 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,462 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,463 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,464 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,466 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,467 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# 2020-11-16 14:53:27,587 [INFO ] pool-1-thread-18 ACCESS_LOG - /169.254.255.130:48830 "GET /ping HTTP/1.1" 200 14
# 2020-11-16 14:53:27,598 [INFO ] epollEventLoopGroup-3-2 ACCESS_LOG - /169.254.255.130:48834 "GET /execution-parameters HTTP/1.1" 404 2
# 2020-11-16 14:53:29,934 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:29,966 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,010 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,010 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,013 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,030 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,030 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,042 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,058 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,067 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,080 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,096 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,118 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,133 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,136 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:30,212 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# 2020-11-16 14:53:31,774 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:31,778 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4227
# 2020-11-16 14:53:31,780 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-8
# 2020-11-16 14:53:31,874 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:31,877 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4326
# 2020-11-16 14:53:31,877 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-9
# 2020-11-16 14:53:31,907 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:31,910 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4360
# 2020-11-16 14:53:31,910 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-14
# 2020-11-16 14:53:31,911 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:31,913 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4362
# 2020-11-16 14:53:31,914 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-3
# 2020-11-16 14:53:31,923 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:31,925 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4375
# 2020-11-16 14:53:31,971 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:31,973 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4422
# 2020-11-16 14:53:31,975 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:31,774 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:31,778 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4227
# 2020-11-16 14:53:31,780 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-8
# 2020-11-16 14:53:31,874 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:31,877 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4326
# 2020-11-16 14:53:31,877 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-9
# 2020-11-16 14:53:31,907 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:31,910 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4360
# 2020-11-16 14:53:31,910 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-14
# 2020-11-16 14:53:31,911 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:31,913 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4362
# 2020-11-16 14:53:31,914 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-3
# 2020-11-16 14:53:31,923 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:31,925 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4375
# 2020-11-16 14:53:31,971 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:31,973 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4422
# 2020-11-16 14:53:31,975 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:31,977 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4426
# 2020-11-16 14:53:32,000 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-4
# 2020-11-16 14:53:32,000 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-16
# 2020-11-16 14:53:32,000 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-6
# 2020-11-16 14:53:32,015 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,015 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,017 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4467
# 2020-11-16 14:53:32,017 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-12
# 2020-11-16 14:53:32,017 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4473
# 2020-11-16 14:53:32,017 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-1
# 2020-11-16 14:53:32,048 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,049 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4499
# 2020-11-16 14:53:32,050 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-15
# 2020-11-16 14:53:32,055 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,057 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4506
# 2020-11-16 14:53:32,057 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-11
# 2020-11-16 14:53:32,072 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,074 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4524
# 2020-11-16 14:53:32,074 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-5
# 2020-11-16 14:53:32,107 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,108 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4558
# 2020-11-16 14:53:32,109 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-2
# 2020-11-16 14:53:32,147 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,149 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4598
# 2020-11-16 14:53:32,149 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-7
# 2020-11-16 14:53:32,171 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,173 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4629
# 2020-11-16 14:53:32,173 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-10
# 2020-11-16 14:53:32,256 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,257 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4706
# 2020-11-16 14:53:32,258 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-13
# 2020-11-16 14:53:31,977 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4426
# 2020-11-16 14:53:32,000 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-4
# 2020-11-16 14:53:32,000 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-16
# 2020-11-16 14:53:32,000 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-6
# 2020-11-16 14:53:32,015 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,015 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,017 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4467
# 2020-11-16 14:53:32,017 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-12
# 2020-11-16 14:53:32,017 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4473
# 2020-11-16 14:53:32,017 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-1
# 2020-11-16 14:53:32,048 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,049 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4499
# 2020-11-16 14:53:32,050 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-15
# 2020-11-16 14:53:32,055 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,057 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4506
# 2020-11-16 14:53:32,057 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-11
# 2020-11-16 14:53:32,072 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,074 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4524
# 2020-11-16 14:53:32,074 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-5
# 2020-11-16 14:53:32,107 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,108 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4558
# 2020-11-16 14:53:32,109 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-2
# 2020-11-16 14:53:32,147 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,149 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4598
# 2020-11-16 14:53:32,149 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-7
# 2020-11-16 14:53:32,171 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,173 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4629
# 2020-11-16 14:53:32,173 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-10
# 2020-11-16 14:53:32,256 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,257 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4706
# 2020-11-16 14:53:32,258 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-13
# 2020-11-16 14:53:33,741 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Prediction counts: Counter({'no': 11384, 'yes': 972})
# 2020-11-16 14:53:33,752 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Label column (y) found in input data. Therefore, evaluating prediction performance...
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - {
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     "accuracy": 0.9189057947555843,
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     "accuracy_score": 0.9189057947555843,
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     "balanced_accuracy_score": 0.7314432005939807,
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     "matthews_corrcoef": 0.5443043841001366,
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     "f1_score": 0.9189057947555843,
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     "classification_report": {
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         "no": {
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "precision": 0.9373682361208714,
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "recall": 0.9736313868613139,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "f1-score": 0.95515574650913,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "support": 10960
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         },
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         "yes": {
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "precision": 0.7026748971193416,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "recall": 0.4892550143266476,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "f1-score": 0.5768581081081082,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "support": 1396
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         },
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         "accuracy": 0.9189057947555843,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         "macro avg": {
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "precision": 0.8200215666201065,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "recall": 0.7314432005939807,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "f1-score": 0.7660069273086192,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "support": 12356
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         },
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         "weighted avg": {
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "precision": 0.9108522195098212,
# 2020-11-16 14:53:34,294 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 2492
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "recall": 0.9189057947555843,
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "f1-score": 0.9124150939348481,
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "support": 12356
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         }
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     }
# 2020-11-16 14:53:34,294 [INFO ] W-9000-model ACCESS_LOG - /169.254.255.130:48842 "POST /invocations HTTP/1.1" 200 4311
# 2020-11-16 14:53:33,741 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Prediction counts: Counter({'no': 11384, 'yes': 972})
# 2020-11-16 14:53:33,752 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Label column (y) found in input data. Therefore, evaluating prediction performance...
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - {
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     "accuracy": 0.9189057947555843,
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     "accuracy_score": 0.9189057947555843,
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     "balanced_accuracy_score": 0.7314432005939807,
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     "matthews_corrcoef": 0.5443043841001366,
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     "f1_score": 0.9189057947555843,
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     "classification_report": {
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         "no": {
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "precision": 0.9373682361208714,
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "recall": 0.9736313868613139,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "f1-score": 0.95515574650913,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "support": 10960
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         },
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         "yes": {
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "precision": 0.7026748971193416,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "recall": 0.4892550143266476,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "f1-score": 0.5768581081081082,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "support": 1396
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         },
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         "accuracy": 0.9189057947555843,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         "macro avg": {
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "precision": 0.8200215666201065,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "recall": 0.7314432005939807,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "f1-score": 0.7660069273086192,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "support": 12356
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         },
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         "weighted avg": {
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "precision": 0.9108522195098212,
# 2020-11-16 14:53:34,294 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 2492
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "recall": 0.9189057947555843,
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "f1-score": 0.9124150939348481,
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "support": 12356
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         }
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     }
# 2020-11-16 14:53:34,294 [INFO ] W-9000-model ACCESS_LOG - /169.254.255.130:48842 "POST /invocations HTTP/1.1" 200 4311
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - }
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Elapsed time: 2.488 seconds
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - }
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Elapsed time: 2.488 seconds
#
# 2020-11-16T14:53:27.608:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# Warning: Calling MMS with mxnet-model-server. Please move to multi-model-server.
# Warning: Calling MMS with mxnet-model-server. Please move to multi-model-server.
# 2020-11-16 14:53:27,207 [INFO ] main com.amazonaws.ml.mms.ModelServer -
# MMS Home: /usr/local/lib/python3.6/site-packages
# Current directory: /
# Temp directory: /home/model-server/tmp
# Number of GPUs: 0
# Number of CPUs: 16
# Max heap size: 13346 M
# Python executable: /usr/local/bin/python3.6
# Config file: /etc/sagemaker-mms.properties
# Inference address: http://0.0.0.0:8080
# Management address: http://0.0.0.0:8080
# Model Store: /.sagemaker/mms/models
# Initial Models: ALL
# Log dir: /logs
# Metrics dir: /logs
# Netty threads: 0
# Netty client threads: 0
# Default workers per model: 16
# Blacklist Regex: N/A
# Maximum Response Size: 6553500
# Maximum Request Size: 6553500
# Preload model: false
# Prefer direct buffer: false
# 2020-11-16 14:53:27,260 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-9000-model
# 2020-11-16 14:53:27,378 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - model_service_worker started with args: --sock-type unix --sock-name /home/model-server/tmp/.mms.sock.9000 --handler sagemaker_mxnet_serving_container.handler_service --model-path /.sagemaker/mms/models/model --model-name model --preload-model false --tmp-dir /home/model-server/tmp
# 2020-11-16 14:53:27,379 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Listening on port: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,379 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - [PID] 108
# 2020-11-16 14:53:27,207 [INFO ] main com.amazonaws.ml.mms.ModelServer -
# MMS Home: /usr/local/lib/python3.6/site-packages
# Current directory: /
# Temp directory: /home/model-server/tmp
# Number of GPUs: 0
# Number of CPUs: 16
# Max heap size: 13346 M
# Python executable: /usr/local/bin/python3.6
# Config file: /etc/sagemaker-mms.properties
# Inference address: http://0.0.0.0:8080
# Management address: http://0.0.0.0:8080
# Model Store: /.sagemaker/mms/models
# Initial Models: ALL
# Log dir: /logs
# Metrics dir: /logs
# Netty threads: 0
# Netty client threads: 0
# Default workers per model: 16
# Blacklist Regex: N/A
# Maximum Response Size: 6553500
# Maximum Request Size: 6553500
# Preload model: false
# Prefer direct buffer: false
# 2020-11-16 14:53:27,260 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-9000-model
# 2020-11-16 14:53:27,378 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - model_service_worker started with args: --sock-type unix --sock-name /home/model-server/tmp/.mms.sock.9000 --handler sagemaker_mxnet_serving_container.handler_service --model-path /.sagemaker/mms/models/model --model-name model --preload-model false --tmp-dir /home/model-server/tmp
# 2020-11-16 14:53:27,379 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Listening on port: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,379 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - [PID] 108
# 2020-11-16 14:53:27,379 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - MMS worker started.
# 2020-11-16 14:53:27,379 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Python runtime: 3.6.10
# 2020-11-16 14:53:27,380 [INFO ] main com.amazonaws.ml.mms.wlm.ModelManager - Model model loaded.
# 2020-11-16 14:53:27,385 [INFO ] main com.amazonaws.ml.mms.ModelServer - Initialize Inference server with: EpollServerSocketChannel.
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# 2020-11-16 14:53:27,393 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# ...
# 2020-11-16 14:53:32,107 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,108 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4558
# 2020-11-16 14:53:32,109 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-2
# 2020-11-16 14:53:32,147 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,149 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4598
# 2020-11-16 14:53:32,149 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-7
# 2020-11-16 14:53:32,171 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,173 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4629
# 2020-11-16 14:53:32,173 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-10
# 2020-11-16 14:53:32,256 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,257 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4706
# 2020-11-16 14:53:32,258 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-13
# 2020-11-16 14:53:31,977 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4426
# 2020-11-16 14:53:32,000 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-4
# 2020-11-16 14:53:32,000 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-16
# 2020-11-16 14:53:32,000 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-6
# 2020-11-16 14:53:32,015 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,015 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,017 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4467
# 2020-11-16 14:53:32,017 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-12
# 2020-11-16 14:53:32,017 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4473
# 2020-11-16 14:53:32,017 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-1
# 2020-11-16 14:53:32,048 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,049 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4499
# 2020-11-16 14:53:32,050 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-15
# 2020-11-16 14:53:32,055 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,057 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4506
# 2020-11-16 14:53:32,057 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-11
# 2020-11-16 14:53:32,072 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,074 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4524
# 2020-11-16 14:53:32,074 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-5
# 2020-11-16 14:53:32,107 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,108 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4558
# 2020-11-16 14:53:32,109 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-2
# 2020-11-16 14:53:32,147 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,149 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4598
# 2020-11-16 14:53:32,149 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-7
# 2020-11-16 14:53:32,171 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,173 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4629
# 2020-11-16 14:53:32,173 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-10
# 2020-11-16 14:53:32,256 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['code', 'learner.pkl', 'models', 'MAR-INF']
# 2020-11-16 14:53:32,257 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4706
# 2020-11-16 14:53:32,258 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-13
# 2020-11-16 14:53:33,741 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Prediction counts: Counter({'no': 11384, 'yes': 972})
# 2020-11-16 14:53:33,752 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Label column (y) found in input data. Therefore, evaluating prediction performance...
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - {
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     "accuracy": 0.9189057947555843,
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     "accuracy_score": 0.9189057947555843,
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     "balanced_accuracy_score": 0.7314432005939807,
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     "matthews_corrcoef": 0.5443043841001366,
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     "f1_score": 0.9189057947555843,
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     "classification_report": {
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         "no": {
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "precision": 0.9373682361208714,
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "recall": 0.9736313868613139,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "f1-score": 0.95515574650913,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "support": 10960
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         },
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         "yes": {
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "precision": 0.7026748971193416,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "recall": 0.4892550143266476,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "f1-score": 0.5768581081081082,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "support": 1396
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         },
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         "accuracy": 0.9189057947555843,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         "macro avg": {
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "precision": 0.8200215666201065,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "recall": 0.7314432005939807,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "f1-score": 0.7660069273086192,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "support": 12356
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         },
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         "weighted avg": {
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "precision": 0.9108522195098212,
# 2020-11-16 14:53:34,294 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 2492
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "recall": 0.9189057947555843,
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "f1-score": 0.9124150939348481,
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "support": 12356
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         }
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     }
# 2020-11-16 14:53:34,294 [INFO ] W-9000-model ACCESS_LOG - /169.254.255.130:48842 "POST /invocations HTTP/1.1" 200 4311
# 2020-11-16 14:53:33,741 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Prediction counts: Counter({'no': 11384, 'yes': 972})
# 2020-11-16 14:53:33,752 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Label column (y) found in input data. Therefore, evaluating prediction performance...
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - {
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     "accuracy": 0.9189057947555843,
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     "accuracy_score": 0.9189057947555843,
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     "balanced_accuracy_score": 0.7314432005939807,
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     "matthews_corrcoef": 0.5443043841001366,
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     "f1_score": 0.9189057947555843,
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     "classification_report": {
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         "no": {
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "precision": 0.9373682361208714,
# 2020-11-16 14:53:34,292 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "recall": 0.9736313868613139,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "f1-score": 0.95515574650913,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "support": 10960
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         },
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         "yes": {
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "precision": 0.7026748971193416,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "recall": 0.4892550143266476,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "f1-score": 0.5768581081081082,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "support": 1396
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         },
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         "accuracy": 0.9189057947555843,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         "macro avg": {
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "precision": 0.8200215666201065,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "recall": 0.7314432005939807,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "f1-score": 0.7660069273086192,
# 2020-11-16 14:53:34,293 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "support": 12356
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         },
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         "weighted avg": {
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "precision": 0.9108522195098212,
# 2020-11-16 14:53:34,294 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 2492
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "recall": 0.9189057947555843,
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "f1-score": 0.9124150939348481,
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -             "support": 12356
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -         }
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -     }
# 2020-11-16 14:53:34,294 [INFO ] W-9000-model ACCESS_LOG - /169.254.255.130:48842 "POST /invocations HTTP/1.1" 200 4311
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - }
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Elapsed time: 2.488 seconds
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - }
# 2020-11-16 14:53:34,294 [INFO ] W-model-8-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Elapsed time: 2.488 seconds

# %%
# !aws s3 ls {output_path}
# Out:
# 2020-11-16 14:53:35      38040 test.csv.out

# %%
# !aws s3 cp {output_path}test.csv.out test.csv.out
# Out:
# download: s3://sagemaker-us-east-1-308961792850/sagemaker/autogluon-tabular/output/test.csv.out to ./test.csv.out

# %%
# !head -n 5 test.csv.out
# Out:
# no
# no
# no
# no
# no

# %% [markdown]
# ### Step 7: Clean-up

# %% [markdown]
# 예측작업이 끝나면 추가 과금을 피하기 위해 엔드포인트를 삭제합니다.

# %%
predictor.delete_endpoint()

# %%
#Finally, delete the model you created.
predictor.delete_model()

# %% [markdown]
# 마지막으로, 테스트만을 목적으로 AWS 마켓플레이스에 subscribe한 경우 테스트 이후 unsubscribe를 할 수 있습니다.
# subscription을 취소하기 전에 해당 알고리즘이나 모델 패키지로부터 배포된 [모델](https://console.aws.amazon.com/sagemaker/home#/models)에 있지 않은지 확인합니다. - 모델과 연관된 컨테이너를 통해 이를 확인할 수 있습니다.
#
# AWS 마켓플레이스 unsubscribe 하기
# 1. [__Your Software subscriptions page__](https://aws.amazon.com/marketplace/ai/library?productType=ml&ref_=lbr_tab_ml)의 __Machine Learning__ 탭으로 이동합니다.
# 1. subscription을 취소하고자 하는 리스트로 이동한 후 __Cancel Subscription__을 클릭합니다.
